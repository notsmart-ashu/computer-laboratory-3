# %%
import xmlrpc.client

# Connect client to server
client = xmlrpc.client.ServerProxy("http://127.0.0.1:8000/")

while True:
    print("\n1. Concatenate Strings")
    print("2. Exit and Stop Server")

    choice = input("Enter your choice: ")

    if choice == "1":

        str1 = input("Enter first string: ")
        str2 = input("Enter second string: ")

        try:
            result = client.concatenate(str1, str2)
            print("Concatenated String =", result)

        except Exception as e:
            print("Error:", e)

    elif choice == "2":

        try:
            print(client.stop())
        except:
            pass

        break

    else:
        print("Invalid choice")
# Out:
# 1. Concatenate Strings
# 2. Exit and Stop Server
# Enter your choice:  1
# Enter first string:  hello
# Enter second string:  world
# Concatenated String = hello  world
#
# 1. Concatenate Strings
# 2. Exit and Stop Server
# Enter your choice:  ashh
# Invalid choice
#
# 1. Concatenate Strings
# 2. Exit and Stop Server
# Enter your choice:  1
# Enter first string:  ashuu
# Enter second string:  tosh
# Concatenated String = ashuu tosh
#
# 1. Concatenate Strings
# 2. Exit and Stop Server
# Enter your choice:  2
# Server stopped
