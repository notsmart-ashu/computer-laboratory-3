# %%
from xmlrpc.server import SimpleXMLRPCServer
import threading

# Concatenate function
def concatenate(str1, str2):
    print(f"Received: {str1} and {str2}")
    return str1 + " " + str2

# Stop server function
def stop_server():
    print("Server shutting down...")
    threading.Thread(target=server.shutdown).start()
    return "Server stopped"

# Create server
server = SimpleXMLRPCServer(("127.0.0.1", 8000), allow_none=True)

print("Server started on port 8000...")

# Register functions
server.register_function(concatenate, "concatenate")
server.register_function(stop_server, "stop")

# Run server
server.serve_forever()

print("Server closed.")
# Out:
# Server started on port 8000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 25
#      22 server.register_function(stop_server, "stop")
#      24 # Run server
# ---> 25 server.serve_forever()
#      27 print("Server closed.")
#
# File ~\anaconda3\Lib\socketserver.py:235, in BaseServer.serve_forever(self, poll_interval)
#     232 selector.register(self, selectors.EVENT_READ)
#     234 while not self.__shutdown_request:
# --> 235     ready = selector.select(poll_interval)
#     236     # bpo-35017: shutdown() called during select(), exit immediately.
#     237     if self.__shutdown_request:
#
# File ~\anaconda3\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File ~\anaconda3\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
